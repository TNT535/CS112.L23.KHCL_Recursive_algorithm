# %% [markdown]
# Chú ý: các bài toán đều được triển khai bằng tài khoản 19521043

# %% [markdown]
# # Phân số

# %% [markdown]
# Cho 2 phân số đúng và tối giản $\frac{a}{b}$ , $\frac{c}{d}$  . Mỗi phép biến đổi là tăng a và b lên 1, sau đó giản ước phân số nhận được.
#
# Hãy xác định sau bao nhiêu bước biến đổi từ phân số thứ nhất ban đầu nhận được phân số thứ 2 đã cho.
#
# Dữ liệu: Vào từ thiết bị nhập chuẩn gồm 4 dòng, mỗi dòng chứa 1 số nguyên a, b, c, d, 0 < a < b ≤$10^5$, 0 < c < d ≤ $10^5$, a và b nguyên tố cùng nhau, c và d nguyên tố cùng nhau  $\frac{a}{b}$ ≠ $\frac{c}{d}$
#
# Kết quả: Đưa ra thiết bị xuất chuẩn số 0 nếu không có cách biến đổi hoặc một số nguyên – số lượng phép biến đổi.
#
# Ví dụ:
#
# INPUT
#
# 1 6 2 3
#
# OUTPUT
#
# 5

# %% [markdown]
# # 1. Abstraction:

# %% [markdown]
# -	Tính số lần biến đổi phân số $\frac{a}{b}$ thành phân số $\frac{c}{d}$ .
# Quy tắc biến đổi: a, b tăng thêm 1, tối giản phân số (nếu có thể).

# %% [markdown]
# # 2. Pattern Recognition:

# %% [markdown]
# -	Kỹ thuật: Brute force

# %% [markdown]
# # 3. Algorithm:

# %% [markdown]
# -	Ý tưởng: Sử dụng kỹ thuật vét cạn đếm và kiểm tra lần lượt từng bước biến đổi. Nếu phân số $\frac{a}{b}$  bằng $\frac{c}{d}$  thì dừng trả về kết quả biến đếm, nếu  $\frac{a}{b}$ > $\frac{c}{d}$  thì dừng và xuất 0 vì  không thể biến đổi về $\frac{c}{d}$ được nữa.
# -	Lưu đồ thuật toán:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 4. Đánh giá độ phức tạp thuật toán:

# %% [markdown]
# O(n)

# %% [markdown]
# # 5. Programming:

# %%
import math

a = int(input())
b = int(input())
c = int(input())
d = int(input())
s = 0
f = 0
h = float(c) / d


def gcd(m, n):
    if m < n:
        m, n = n, m
    while m % n != 0:
        m, n = n, m % n
    return n


while f < h:
    a = a + 1
    b = b + 1
    e = gcd(a, b)
    a = a / e
    b = b / e
    s = s + 1
    f = float(a) / b
if f == h:
    print(s)
else:
    print(0)

# %% [markdown]
# # 6. Result

# %% [markdown]
# Vượt qua tất cả các test case trong thời gian yêu cầu.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
